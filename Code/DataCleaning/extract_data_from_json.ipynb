# %% [markdown]
# Import libraries

# %%
import pandas as pd
import requests
from datetime import datetime
import time
import os
import json
import numpy as np

# %%
# set paths and folders
data_path = '../../Data/20230414DataJobSearch/'
folders = ['2023-04-14-job-search-location-USA', '2023-04-14-job-search-location-DC']

# %% [markdown]
# ### Metadata and parameters

# %%
# init empty list
metadata_and_parameters = []

# loop through all files
for folder in folders:
    
    data_path_and_folder = f'{data_path}{folder}'
    
    for file in os.listdir(data_path_and_folder):
        if file.endswith(".json"):
            full_path = os.path.join(data_path_and_folder, file)
            
            # open json
            with open(full_path, 'r') as f:
                json_data = json.load(f)
            
            # store file and folder name
            json_data['search_name'] = file
            json_data['search_location'] = folder
            
            # append
            metadata_and_parameters.append(json_data)

# convert to dataframe
metadata_and_parameters = pd.json_normalize(metadata_and_parameters)

# drop results and chips
metadata_and_parameters = metadata_and_parameters.drop(['jobs_results', 'chips'], axis=1)

# clean search name and location
metadata_and_parameters['search_name'] = metadata_and_parameters['search_name'].str.replace('.json', '', regex=False)
metadata_and_parameters['search_location'] = metadata_and_parameters['search_location'].str.replace('2023-04-14-job-search-location-', '', regex=False)

# fix column names
metadata_and_parameters = metadata_and_parameters.rename(columns=lambda x: x.replace('search_metadata.', 'metadata_'))
metadata_and_parameters = metadata_and_parameters.rename(columns=lambda x: x.replace('search_parameters.', 'parameters_'))

# check
display(metadata_and_parameters.shape)
display(metadata_and_parameters.head())
# Out:
# (85, 19)
#                      search_name search_location               metadata_id  \
# 0                  block-chain-1             USA  643db9ec224db12213cd421b
# 1               data-scientist-4             USA  643db97e5fc493f4ef82a469
# 2  natural-language-processing-1             USA  643db9f96073930b48d5359a
# 3       reinforcement-learning-4             USA  643db9ce58762b07c185c1b1
# 4              neural-networks-4             USA  643db99ab7b1cc54dd45c12f
#
#   metadata_status                             metadata_json_endpoint  \
# 0         Success  https://serpapi.com/searches/a7e3d320a9075f00/...
# 1         Success  https://serpapi.com/searches/a980517c7e93b15a/...
# 2         Success  https://serpapi.com/searches/6806a6ad5db11221/...
# 3         Success  https://serpapi.com/searches/4355f1f2ab30af9b/...
# 4         Success  https://serpapi.com/searches/1260623261e4e9be/...
#
#        metadata_created_at    metadata_processed_at  \
# 0  2023-04-17 21:28:12 UTC  2023-04-17 21:28:12 UTC
# 1  2023-04-17 21:26:22 UTC  2023-04-17 21:26:22 UTC
# 2  2023-04-17 21:28:25 UTC  2023-04-17 21:28:25 UTC
# 3  2023-04-17 21:27:42 UTC  2023-04-17 21:27:42 UTC
# 4  2023-04-17 21:26:50 UTC  2023-04-17 21:26:50 UTC
#
#                             metadata_google_jobs_url  \
# 0  https://www.google.com/search?q=block+chain&ib...
# 1  https://www.google.com/search?q=data+scientist...
# 2  https://www.google.com/search?q=natural+langua...
# 3  https://www.google.com/search?q=reinforcement+...
# 4  https://www.google.com/search?q=neural+network...
#
#                               metadata_raw_html_file  \
# 0  https://serpapi.com/searches/a7e3d320a9075f00/...
# 1  https://serpapi.com/searches/a980517c7e93b15a/...
# 2  https://serpapi.com/searches/6806a6ad5db11221/...
# 3  https://serpapi.com/searches/4355f1f2ab30af9b/...
# 4  https://serpapi.com/searches/1260623261e4e9be/...
#
#    metadata_total_time_taken                 parameters_q parameters_engine  \
# 0                       4.09                  block chain       google_jobs
# 1                       1.84               data scientist       google_jobs
# 2                       2.50  natural language processing       google_jobs
# 3                       2.69       reinforcement learning       google_jobs
# 4                       0.69              neural networks       google_jobs
#
#                 parameters_uule parameters_google_domain parameters_hl  \
# 0  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 1  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 2  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 3  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 4  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
#
#   parameters_gl  parameters_start error search_information.jobs_results_state
# 0            us                10   NaN                                   NaN
# 1            us                40   NaN                                   NaN
# 2            us                10   NaN                                   NaN
# 3            us                40   NaN                                   NaN
# 4            us                40   NaN                                   NaN

# %%
# remove searches that failed
metadata_and_parameters = metadata_and_parameters[~metadata_and_parameters['search_information.jobs_results_state'].isin(['Fully empty'])]

# drop columns that indicate failed search
metadata_and_parameters = metadata_and_parameters.drop(['error', 'search_information.jobs_results_state'], axis=1)

# remove duplicates if any
metadata_and_parameters = metadata_and_parameters.drop_duplicates()

# check
display(metadata_and_parameters.shape)
display(metadata_and_parameters.head())
# Out:
# (83, 17)
#                      search_name search_location               metadata_id  \
# 0                  block-chain-1             USA  643db9ec224db12213cd421b
# 1               data-scientist-4             USA  643db97e5fc493f4ef82a469
# 2  natural-language-processing-1             USA  643db9f96073930b48d5359a
# 3       reinforcement-learning-4             USA  643db9ce58762b07c185c1b1
# 4              neural-networks-4             USA  643db99ab7b1cc54dd45c12f
#
#   metadata_status                             metadata_json_endpoint  \
# 0         Success  https://serpapi.com/searches/a7e3d320a9075f00/...
# 1         Success  https://serpapi.com/searches/a980517c7e93b15a/...
# 2         Success  https://serpapi.com/searches/6806a6ad5db11221/...
# 3         Success  https://serpapi.com/searches/4355f1f2ab30af9b/...
# 4         Success  https://serpapi.com/searches/1260623261e4e9be/...
#
#        metadata_created_at    metadata_processed_at  \
# 0  2023-04-17 21:28:12 UTC  2023-04-17 21:28:12 UTC
# 1  2023-04-17 21:26:22 UTC  2023-04-17 21:26:22 UTC
# 2  2023-04-17 21:28:25 UTC  2023-04-17 21:28:25 UTC
# 3  2023-04-17 21:27:42 UTC  2023-04-17 21:27:42 UTC
# 4  2023-04-17 21:26:50 UTC  2023-04-17 21:26:50 UTC
#
#                             metadata_google_jobs_url  \
# 0  https://www.google.com/search?q=block+chain&ib...
# 1  https://www.google.com/search?q=data+scientist...
# 2  https://www.google.com/search?q=natural+langua...
# 3  https://www.google.com/search?q=reinforcement+...
# 4  https://www.google.com/search?q=neural+network...
#
#                               metadata_raw_html_file  \
# 0  https://serpapi.com/searches/a7e3d320a9075f00/...
# 1  https://serpapi.com/searches/a980517c7e93b15a/...
# 2  https://serpapi.com/searches/6806a6ad5db11221/...
# 3  https://serpapi.com/searches/4355f1f2ab30af9b/...
# 4  https://serpapi.com/searches/1260623261e4e9be/...
#
#    metadata_total_time_taken                 parameters_q parameters_engine  \
# 0                       4.09                  block chain       google_jobs
# 1                       1.84               data scientist       google_jobs
# 2                       2.50  natural language processing       google_jobs
# 3                       2.69       reinforcement learning       google_jobs
# 4                       0.69              neural networks       google_jobs
#
#                 parameters_uule parameters_google_domain parameters_hl  \
# 0  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 1  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 2  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 3  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
# 4  w+CAIQICINVW5pdGVkIFN0YXRlcw               google.com            en
#
#   parameters_gl  parameters_start
# 0            us                10
# 1            us                40
# 2            us                10
# 3            us                40
# 4            us                40

# %%
# export
metadata_and_parameters.to_csv('../../Data/metadata_and_parameters.csv', index=False)

# %% [markdown]
# ### Job Results

# %%
# init empty list
jobs_results = []

# loop through all files
for folder in folders:
    data_path_and_folder = os.path.join(data_path, folder)

    for file in os.listdir(data_path_and_folder):
        
        if True == False: # set to true to debug
            print(folder)
            print(file)
        
        
        if file.endswith(".json"):
            full_path = os.path.join(data_path_and_folder, file)

            # open json
            with open(full_path, 'r') as f:
                json_data = json.load(f)
            
            # check if the file has failed search columns and skip if yes
            try:
                json_data["search_information"]["jobs_results_state"]                
                continue
            
            except:       
                pass
                

            # select only job results
            json_data = json_data["jobs_results"]

            
            for job in json_data:
                highlights_dict = {}
                
                # create job highlight cols
                for highlight in job["job_highlights"]:
                    if "title" in highlight and "items" in highlight: # check if there are highlights with titles, some don't have it
                        highlights_dict[highlight["title"]] = "\n".join(highlight["items"])

                jobs_results.append({
                    "title": job["title"],
                    "company_name": job["company_name"],
                    "location": job["location"].strip(),
                    "via": job["via"],
                    "description": job["description"],
                    "qualifications": highlights_dict.get("Qualifications", ""),
                    "responsibilities": highlights_dict.get("Responsibilities", ""),
                    "benefits": highlights_dict.get("Benefits", ""),
                    #"extensions": job["extensions"],
                    "detected_extensions": job["detected_extensions"],
                    "job_id": job["job_id"],
                    "search_name": file,
                    "search_location": folder
                })
                
            
# convert to dataframe
jobs_results = pd.DataFrame(jobs_results)

# clean search name and location
jobs_results['search_name'] = jobs_results['search_name'].str.replace('.json', '', regex=False)
jobs_results['search_location'] = jobs_results['search_location'].str.replace('2023-04-14-job-search-location-', '', regex=False)

# check
display(jobs_results.shape)
display(jobs_results.head())
# Out:
# (823, 12)
#                                                title company_name  \
# 0                Senior Blockchain Software Engineer       Truist
# 1  Get twitter accounts that are tied to blockcha...       Upwork
# 2                                 Blockchain Analyst       Allium
# 3                     Full Stack Blockchain Engineer       geojam
# 4  Blockchain Engineer - Apps Platform at Exodus ...       Exodus
#
#           location                        via  \
# 0         Anywhere           via ZipRecruiter
# 1         Anywhere                 via Upwork
# 2     New York, NY                   via Jobs
# 3  Los Angeles, CA              via AngelList
# 4    Livermore, CA  via Livermore, CA - Geebo
#
#                                          description  \
# 0  The position is described below. If you want t...
# 1  I am looking for a list of blockchain addresse...
# 2  About the role\n• Sherlock & Enola Holmes leve...
# 3  Who We Are\n\nLaunched in 2020, Geojam is a so...
# 4  Exodus is looking for a detail-orientated Bloc...
#
#                                       qualifications  \
# 0  Language Fluency: English (Required)\nThe requ...
# 1
# 2  Ability to parse and understand EVM (and/or So...
# 3  We’re looking for a capable generalist enginee...
# 4
#
#                                     responsibilities  \
# 0  Deliver highly complex solutions with signific...
# 1
# 2  Tackling interesting problems - we are ingesti...
# 3  You will be designing and building our core so...
# 4
#
#                                             benefits  \
# 0  General Description of Available Benefits for ...
# 1
# 2  An accelerated growth trajectory - you will ha...
# 3  We’re wrapping up our presale for $JAM, so you...
# 4
#
#                                  detected_extensions  \
# 0  {'posted_at': '7 days ago', 'schedule_type': '...
# 1  {'posted_at': '4 days ago', 'schedule_type': '...
# 2                     {'schedule_type': 'Full-time'}
# 3                     {'schedule_type': 'Full-time'}
# 4  {'posted_at': '2 days ago', 'schedule_type': '...
#
#                                               job_id    search_name  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...  block-chain-1
# 1  eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...  block-chain-1
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...  block-chain-1
# 3  eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...  block-chain-1
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...  block-chain-1
#
#   search_location
# 0             USA
# 1             USA
# 2             USA
# 3             USA
# 4             USA

# %%
# expand the detected extensions col

# get all possible keys
detected_extensions_keys = set()
for extensions in jobs_results['detected_extensions']:
    
    detected_extensions_keys.update(extensions.keys())

# create a new df
detected_extensions = []
for i in jobs_results['detected_extensions']:
    
    ext_dict = {}
    for key in detected_extensions_keys:
        ext_dict[key] = i.get(key, np.nan) # get key or nan otherwise
        
    detected_extensions.append(ext_dict)

detected_extensions = pd.DataFrame(detected_extensions)


#check
display(detected_extensions.head())
# Out:
#     posted_at schedule_type         salary work_from_home commute_time
# 0  7 days ago     Full-time            NaN           True          NaN
# 1  4 days ago    Contractor            NaN           True          NaN
# 2         NaN     Full-time            NaN            NaN          NaN
# 3         NaN     Full-time            NaN            NaN          NaN
# 4  2 days ago     Full-time  20–28 an hour            NaN          NaN

# %%
# concat and drop unnecesary column
jobs_results = pd.concat([jobs_results, detected_extensions], axis=1)
jobs_results = jobs_results.drop('detected_extensions', axis=1)

# check
display(jobs_results.shape)
display(jobs_results.head())
# Out:
# (823, 16)
#                                                title company_name  \
# 0                Senior Blockchain Software Engineer       Truist
# 1  Get twitter accounts that are tied to blockcha...       Upwork
# 2                                 Blockchain Analyst       Allium
# 3                     Full Stack Blockchain Engineer       geojam
# 4  Blockchain Engineer - Apps Platform at Exodus ...       Exodus
#
#           location                        via  \
# 0         Anywhere           via ZipRecruiter
# 1         Anywhere                 via Upwork
# 2     New York, NY                   via Jobs
# 3  Los Angeles, CA              via AngelList
# 4    Livermore, CA  via Livermore, CA - Geebo
#
#                                          description  \
# 0  The position is described below. If you want t...
# 1  I am looking for a list of blockchain addresse...
# 2  About the role\n• Sherlock & Enola Holmes leve...
# 3  Who We Are\n\nLaunched in 2020, Geojam is a so...
# 4  Exodus is looking for a detail-orientated Bloc...
#
#                                       qualifications  \
# 0  Language Fluency: English (Required)\nThe requ...
# 1
# 2  Ability to parse and understand EVM (and/or So...
# 3  We’re looking for a capable generalist enginee...
# 4
#
#                                     responsibilities  \
# 0  Deliver highly complex solutions with signific...
# 1
# 2  Tackling interesting problems - we are ingesti...
# 3  You will be designing and building our core so...
# 4
#
#                                             benefits  \
# 0  General Description of Available Benefits for ...
# 1
# 2  An accelerated growth trajectory - you will ha...
# 3  We’re wrapping up our presale for $JAM, so you...
# 4
#
#                                               job_id    search_name  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...  block-chain-1
# 1  eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...  block-chain-1
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...  block-chain-1
# 3  eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...  block-chain-1
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...  block-chain-1
#
#   search_location   posted_at schedule_type         salary work_from_home  \
# 0             USA  7 days ago     Full-time            NaN           True
# 1             USA  4 days ago    Contractor            NaN           True
# 2             USA         NaN     Full-time            NaN            NaN
# 3             USA         NaN     Full-time            NaN            NaN
# 4             USA  2 days ago     Full-time  20–28 an hour            NaN
#
#   commute_time
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# check missingness
jobs_results.isnull().sum()
# Out:
# title                 0
# company_name          0
# location              0
# via                   0
# description           0
# qualifications        0
# responsibilities      0
# benefits              0
# job_id                0
# search_name           0
# search_location       0
# posted_at           293
# schedule_type         1
# salary              690
# work_from_home      646
# commute_time        822
# dtype: int64

# %%
# keep only schedule_type
jobs_results = jobs_results.drop(['posted_at', 'work_from_home', 'commute_time', 'salary'], axis=1)

# fill empty shedule type
jobs_results['schedule_type'] = jobs_results['schedule_type'].fillna('Not Specified')

# %%
# remove duplicates if any based on job id
jobs_results = jobs_results.drop_duplicates(subset=['title', 'company_name', 'location'])

# check
display(jobs_results.shape)
display(jobs_results.head())
# Out:
# (591, 12)
#                                                title company_name  \
# 0                Senior Blockchain Software Engineer       Truist
# 1  Get twitter accounts that are tied to blockcha...       Upwork
# 2                                 Blockchain Analyst       Allium
# 3                     Full Stack Blockchain Engineer       geojam
# 4  Blockchain Engineer - Apps Platform at Exodus ...       Exodus
#
#           location                        via  \
# 0         Anywhere           via ZipRecruiter
# 1         Anywhere                 via Upwork
# 2     New York, NY                   via Jobs
# 3  Los Angeles, CA              via AngelList
# 4    Livermore, CA  via Livermore, CA - Geebo
#
#                                          description  \
# 0  The position is described below. If you want t...
# 1  I am looking for a list of blockchain addresse...
# 2  About the role\n• Sherlock & Enola Holmes leve...
# 3  Who We Are\n\nLaunched in 2020, Geojam is a so...
# 4  Exodus is looking for a detail-orientated Bloc...
#
#                                       qualifications  \
# 0  Language Fluency: English (Required)\nThe requ...
# 1
# 2  Ability to parse and understand EVM (and/or So...
# 3  We’re looking for a capable generalist enginee...
# 4
#
#                                     responsibilities  \
# 0  Deliver highly complex solutions with signific...
# 1
# 2  Tackling interesting problems - we are ingesti...
# 3  You will be designing and building our core so...
# 4
#
#                                             benefits  \
# 0  General Description of Available Benefits for ...
# 1
# 2  An accelerated growth trajectory - you will ha...
# 3  We’re wrapping up our presale for $JAM, so you...
# 4
#
#                                               job_id    search_name  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...  block-chain-1
# 1  eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...  block-chain-1
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...  block-chain-1
# 3  eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...  block-chain-1
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...  block-chain-1
#
#   search_location schedule_type
# 0             USA     Full-time
# 1             USA    Contractor
# 2             USA     Full-time
# 3             USA     Full-time
# 4             USA     Full-time

# %%
# confirm no duplicates
jobs_results['job_id'].nunique()
# Out:
# 591

# %%
# format
jobs_results['category'] = jobs_results['search_name'].str.replace('-', ' ') # replace dashes
jobs_results['category'] = jobs_results['category'].str.title() # capitalize each word
jobs_results['category'] = jobs_results['category'].str.replace('\d+', '', regex=True) # remove the numbers

display(jobs_results.head())
# Out:
#                                                title company_name  \
# 0                Senior Blockchain Software Engineer       Truist
# 1  Get twitter accounts that are tied to blockcha...       Upwork
# 2                                 Blockchain Analyst       Allium
# 3                     Full Stack Blockchain Engineer       geojam
# 4  Blockchain Engineer - Apps Platform at Exodus ...       Exodus
#
#           location                        via  \
# 0         Anywhere           via ZipRecruiter
# 1         Anywhere                 via Upwork
# 2     New York, NY                   via Jobs
# 3  Los Angeles, CA              via AngelList
# 4    Livermore, CA  via Livermore, CA - Geebo
#
#                                          description  \
# 0  The position is described below. If you want t...
# 1  I am looking for a list of blockchain addresse...
# 2  About the role\n• Sherlock & Enola Holmes leve...
# 3  Who We Are\n\nLaunched in 2020, Geojam is a so...
# 4  Exodus is looking for a detail-orientated Bloc...
#
#                                       qualifications  \
# 0  Language Fluency: English (Required)\nThe requ...
# 1
# 2  Ability to parse and understand EVM (and/or So...
# 3  We’re looking for a capable generalist enginee...
# 4
#
#                                     responsibilities  \
# 0  Deliver highly complex solutions with signific...
# 1
# 2  Tackling interesting problems - we are ingesti...
# 3  You will be designing and building our core so...
# 4
#
#                                             benefits  \
# 0  General Description of Available Benefits for ...
# 1
# 2  An accelerated growth trajectory - you will ha...
# 3  We’re wrapping up our presale for $JAM, so you...
# 4
#
#                                               job_id    search_name  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...  block-chain-1
# 1  eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...  block-chain-1
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...  block-chain-1
# 3  eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...  block-chain-1
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...  block-chain-1
#
#   search_location schedule_type      category
# 0             USA     Full-time  Block Chain
# 1             USA    Contractor  Block Chain
# 2             USA     Full-time  Block Chain
# 3             USA     Full-time  Block Chain
# 4             USA     Full-time  Block Chain

# %%
# export
jobs_results.to_csv('../../Data/jobs_results.csv', index=False)
